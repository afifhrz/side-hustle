# %% [markdown]
# # Number 2

# %%
import wooldridge as woo

data_load = woo.data('bwght')
data_load
# Out:
#       faminc  cigtax    cigprice  bwght  fatheduc  motheduc  parity  male  \
# 0       13.5    16.5  122.300003    109      12.0      12.0       1     1
# 1        7.5    16.5  122.300003    133       6.0      12.0       2     1
# 2        0.5    16.5  122.300003    129       NaN      12.0       2     0
# 3       15.5    16.5  122.300003    126      12.0      12.0       2     1
# 4       27.5    16.5  122.300003    134      14.0      12.0       2     1
# ...      ...     ...         ...    ...       ...       ...     ...   ...
# 1383    27.5    30.0  138.300003    110      12.0      12.0       4     1
# 1384     5.5    30.0  138.300003    146       NaN      16.0       2     1
# 1385    65.0     8.0  118.599998    135      18.0      16.0       2     0
# 1386    27.5     8.0  118.599998    118       NaN      14.0       2     0
# 1387    37.5     8.0  118.599998    111      16.0      13.0       2     0
#
#       white  cigs    lbwght  bwghtlbs  packs   lfaminc
# ...

# %% [markdown]
# ## 2A

# %%
women_data = data_load[data_load['male']==0]
women_data
# Out:
#       faminc  cigtax    cigprice  bwght  fatheduc  motheduc  parity  male  \
# 2        0.5    16.5  122.300003    129       NaN      12.0       2     0
# 6       65.0    16.5  122.300003    140      16.0      14.0       2     0
# 7       27.5    16.5  122.300003     86      12.0      14.0       2     0
# 8       27.5    16.5  122.300003    121      12.0      17.0       2     0
# 9       37.5    16.5  122.300003    129      16.0      18.0       2     0
# ...      ...     ...         ...    ...       ...       ...     ...   ...
# 1379     1.5    30.0  138.300003    130      10.0      11.0       3     0
# 1382    22.5    30.0  138.300003    135      16.0      16.0       3     0
# 1385    65.0     8.0  118.599998    135      18.0      16.0       2     0
# 1386    27.5     8.0  118.599998    118       NaN      14.0       2     0
# 1387    37.5     8.0  118.599998    111      16.0      13.0       2     0
#
#       white  cigs    lbwght  bwghtlbs  packs   lfaminc
# ...

# %%
print("Number women samples are",len(women_data))
# Out:
# Number women samples are 665

# %%
women_cigs_data = women_data[women_data['cigs']>0]
women_cigs_data
# Out:
#       faminc  cigtax    cigprice  bwght  fatheduc  motheduc  parity  male  \
# 63       0.5    15.0  125.599998    104       NaN      12.0       2     0
# 74      18.5    21.0  127.699997    115       3.0      12.0       1     0
# 94      13.5    21.0  127.699997    109       8.0       8.0       2     0
# 102     11.5    10.0  126.400002    139      12.0      12.0       2     0
# 115     37.5    10.0  126.400002     97      11.0      11.0       2     0
# ...      ...     ...         ...    ...       ...       ...     ...   ...
# 1322    65.0    31.0  150.600006     87      12.0      10.0       1     0
# 1332     4.5    31.0  150.600006    128       NaN      11.0       1     0
# 1344     6.5    30.0  138.300003     91       NaN      11.0       2     0
# 1359    12.5    30.0  138.300003    119      12.0      12.0       3     0
# 1361     5.5    30.0  138.300003    115       NaN      11.0       2     0
#
#       white  cigs    lbwght  bwghtlbs  packs   lfaminc
# ...

# %%
print("Number women samples smoke during pregnancy are",len(women_cigs_data))
# Out:
# Number women samples smoke during pregnancy are 112

# %% [markdown]
# ## 2B

# %%
data_load.describe()
# Out:
#             faminc       cigtax     cigprice        bwght     fatheduc  \
# count  1388.000000  1388.000000  1388.000000  1388.000000  1192.000000
# mean     29.026657    19.552954   130.559006   118.699568    13.186242
# std      18.739285     7.795598    10.244485    20.353964     2.745985
# min       0.500000     2.000000   103.800003    23.000000     1.000000
# 25%      14.500000    15.000000   122.800003   107.000000    12.000000
# 50%      27.500000    20.000000   130.800003   120.000000    12.000000
# 75%      37.500000    26.000000   137.000000   132.000000    16.000000
# max      65.000000    38.000000   152.500000   271.000000    18.000000
#
#           motheduc       parity         male        white         cigs  \
# count  1387.000000  1388.000000  1388.000000  1388.000000  1388.000000
# mean     12.935833     1.632565     0.520893     0.784582     2.087176
# std       2.376728     0.894027     0.499743     0.411260     5.972688
# ...

# %%
print("The average number of cigarettes smoked in a day is",data_load['cigs'].mean())
# Out:
# The average number of cigarettes smoked in a day is 2.0871757925072045

# %%
women_data['cigs'].mean()
# Out:
# 2.0902255639097747

# %%
#Interpration

# %% [markdown]
# ## 2C

# %%
data_load.fatheduc.isnull().sum()
# Out:
# 196

# %%
data_load['fatheduc'].describe()
# Out:
# count    1192.000000
# mean       13.186242
# std         2.745985
# min         1.000000
# 25%        12.000000
# 50%        12.000000
# 75%        16.000000
# max        18.000000
# Name: fatheduc, dtype: float64

# %%
#Interpretation

# %% [markdown]
# # Number 3

# %%
import wooldridge as woo
data_load = woo.data('bwght')
data_load
# Out:
#       faminc  cigtax    cigprice  bwght  fatheduc  motheduc  parity  male  \
# 0       13.5    16.5  122.300003    109      12.0      12.0       1     1
# 1        7.5    16.5  122.300003    133       6.0      12.0       2     1
# 2        0.5    16.5  122.300003    129       NaN      12.0       2     0
# 3       15.5    16.5  122.300003    126      12.0      12.0       2     1
# 4       27.5    16.5  122.300003    134      14.0      12.0       2     1
# ...      ...     ...         ...    ...       ...       ...     ...   ...
# 1383    27.5    30.0  138.300003    110      12.0      12.0       4     1
# 1384     5.5    30.0  138.300003    146       NaN      16.0       2     1
# 1385    65.0     8.0  118.599998    135      18.0      16.0       2     0
# 1386    27.5     8.0  118.599998    118       NaN      14.0       2     0
# 1387    37.5     8.0  118.599998    111      16.0      13.0       2     0
#
#       white  cigs    lbwght  bwghtlbs  packs   lfaminc
# ...

# %% [markdown]
# ## 3A

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
# Sturge
bins = np.round(1 + math.log(len(data_load),2)).astype(int)

plt.figure(figsize=(16,8))
plt.hist(data_load.bwght, alpha=.5, bins=bins)
plt.plot()
# Out:
# []

# %%
# FD
def bins_fd(series):
    numerator = (len(series)**(1/3)*(series.max()-series.min()))
    denominator = (2*(data_load.bwght.quantile(.75)-data_load.bwght.quantile(.25)))

    return int(np.round(numerator/denominator))

plt.figure(figsize=(16,8))
plt.hist(data_load.bwght, alpha=.5, bins=bins_fd(data_load.bwght))
plt.plot()
# Out:
# []

# %% [markdown]
# ## 3B

# %%
import seaborn as sns

plt.figure(figsize=(10,6))
plt.title("Histogram")
sns.histplot(data_load.bwght, stat = "density")
sns.kdeplot(data_load.bwght, color = "red")
plt.plot()
# Out:
# []

# %% [markdown]
# ## 3C

# %%
import scipy.stats as stats

norm_shape = np.random.normal(0, 1, data_load.shape[0])

stats.probplot(norm_shape, dist = "norm", plot = plt)

plt.show()

# %% [markdown]
# ## 3D

# %%
women_smoke = data_load[(data_load['cigs']>0) & (data_load['male']==0)]['bwght']
women_not_smoke = data_load[(data_load['cigs']==0) & (data_load['male']==0)]['bwght']
data = [women_smoke, women_not_smoke]

# %%
plt.figure(figsize=(10,10))
plt.boxplot(data)
plt.ylabel("Cigs")
plt.xticks([1,2],["0","1"])
plt.show()

# %% [markdown]
# # Number 4

# %%
import wooldridge as woo

data_load = woo.data('bwght')
data_load
# Out:
#       faminc  cigtax    cigprice  bwght  fatheduc  motheduc  parity  male  \
# 0       13.5    16.5  122.300003    109      12.0      12.0       1     1
# 1        7.5    16.5  122.300003    133       6.0      12.0       2     1
# 2        0.5    16.5  122.300003    129       NaN      12.0       2     0
# 3       15.5    16.5  122.300003    126      12.0      12.0       2     1
# 4       27.5    16.5  122.300003    134      14.0      12.0       2     1
# ...      ...     ...         ...    ...       ...       ...     ...   ...
# 1383    27.5    30.0  138.300003    110      12.0      12.0       4     1
# 1384     5.5    30.0  138.300003    146       NaN      16.0       2     1
# 1385    65.0     8.0  118.599998    135      18.0      16.0       2     0
# 1386    27.5     8.0  118.599998    118       NaN      14.0       2     0
# 1387    37.5     8.0  118.599998    111      16.0      13.0       2     0
#
#       white  cigs    lbwght  bwghtlbs  packs   lfaminc
# ...

# %% [markdown]
# ## 4 A

# %%
import statsmodels.formula.api as smf

reg = smf.ols('bwght ~ cigs', data = data_load)
result = reg.fit()

result.params
# Out:
# Intercept    119.771900
# cigs          -0.513772
# dtype: float64

# %% [markdown]
# ## 4 B

# %%
parameter = result.params

# %%
#cigs = 0
cigs = 0
parameter[0] + parameter[1]*cigs
# Out:
# 119.77190039834971

# %%
#cigs = 3
cigs = 3
parameter[0] + parameter[1]*cigs
# Out:
# 118.23058411987952

# %% [markdown]
# ## 4 C

# %%
result.resid.sum()
# Out:
# -2.5437429940211587e-11

# %% [markdown]
# ## 4 D

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,9))

plt.scatter(data_load['cigs'], data_load['bwght'])
plt.plot(data_load['cigs'], result.fittedvalues, color = 'orange')

plt.plot()
# Out:
# []
